# %%
from pybaseball import statcast
import pandas as pd
import warnings
from sklearn.preprocessing import StandardScaler

# Enable caching for faster re-runs
from pybaseball import cache
cache.enable()

# Suppress warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Fetch full 2024 dataset
start_date = "2024-03-30"
end_date = "2024-10-01"
df = statcast(start_dt=start_date, end_dt=end_date)

# Save full dataset to avoid data loss
df.to_csv("full_statcast_2024.csv", index=False)

# Check the dataset
print(f"Full dataset shape: {df.shape}")
df.head()
# Out:
# This is a large query, it may take a moment to complete
# 100%|████████████████████████████████████████████████████████████████████████████████| 186/186 [00:10<00:00, 17.37it/s]
# Full dataset shape: (703168, 113)
#     pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 603         CH 2024-10-01           88.1          -1.65           6.12
# 611         CH 2024-10-01           87.1          -1.69           6.17
# 636         CH 2024-10-01           89.7          -1.89           6.14
# 656         FF 2024-10-01           97.5          -1.51           6.32
# 694         CH 2024-10-01           88.6          -1.77           6.19
#
#        player_name  batter  pitcher     events      description  ...  \
# 603  Brieske, Beau  518792   689225  field_out    hit_into_play  ...
# 611  Brieske, Beau  518792   689225       None  swinging_strike  ...
# 636  Brieske, Beau  518792   689225       None             ball  ...
# 656  Brieske, Beau  518792   689225       None             foul  ...
# 694  Brieske, Beau  518792   689225       None     blocked_ball  ...
#
#      n_thruorder_pitcher  n_priorpa_thisgame_player_at_bat  \
# 603                    1                                 1
# 611                    1                                 1
# 636                    1                                 1
# 656                    1                                 1
# 694                    1                                 1
#
#      pitcher_days_since_prev_game  batter_days_since_prev_game  \
# 603                             3                            3
# 611                             3                            3
# 636                             3                            3
# 656                             3                            3
# 694                             3                            3
#
#      pitcher_days_until_next_game batter_days_until_next_game  \
# 603                             1                           1
# 611                             1                           1
# 636                             1                           1
# 656                             1                           1
# 694                             1                           1
#
#     api_break_z_with_gravity api_break_x_arm api_break_x_batter_in arm_angle
# 603                      2.5             1.4                  -1.4      46.4
# 611                     2.45            1.19                 -1.19      44.1
# 636                     2.44            1.33                 -1.33      47.4
# 656                     0.82             0.4                  -0.4      55.0
# 694                     2.32             1.3                  -1.3      47.0
#
# [5 rows x 113 columns]

# %%
# Filter for first-pitch swings and relevant columns
df_first_pitch = df[df['pitch_number'] == 1][[
    'events', 'description', 'pitch_type', 'release_speed', 'launch_speed',
    'launch_angle', 'hit_location', 'bb_type', 'batter', 'pitcher'
]]

# Filter out rows where the 'events' column contains non-swing outcomes
df_first_pitch = df_first_pitch[df_first_pitch['events'].isin(['single', 'double', 'triple', 'home_run', 
                                                               'sac_fly', 'sac_fly_double_play', 
                                                               'field_out', 'force_out', 'grounded_into_double_play',
                                                               'fielders_choice', 'double_play', 'fielders_choice_out'])]

# Display the first few rows of the filtered dataframe
df_first_pitch.head()
# Out:
#          events    description pitch_type  release_speed  launch_speed  \
# 985      double  hit_into_play         SI           95.4          88.2
# 883      single  hit_into_play         FF           92.4          85.9
# 125   field_out  hit_into_play         CH           89.0          84.5
# 445   force_out  hit_into_play         SI           96.3          94.5
# 1045  field_out  hit_into_play         CH           87.1          81.4
#
#       launch_angle  hit_location      bb_type  batter  pitcher
# 985             40          <NA>     fly_ball  682985   623352
# 883             20             7   line_drive  668670   687911
# 125             40             9     fly_ball  514888   669373
# 445            -27             4  ground_ball  678009   664285
# 1045            30             7     fly_ball  514888   669373

# %%
# Fill missing values in 'hit_location' with 0
df_first_pitch['hit_location'] = df_first_pitch['hit_location'].fillna(0)

# Verify that missing values have been filled
df_first_pitch['hit_location'].isna().sum()

df_first_pitch.head()
# Out:
#          events    description pitch_type  release_speed  launch_speed  \
# 985      double  hit_into_play         SI           95.4          88.2
# 883      single  hit_into_play         FF           92.4          85.9
# 125   field_out  hit_into_play         CH           89.0          84.5
# 445   force_out  hit_into_play         SI           96.3          94.5
# 1045  field_out  hit_into_play         CH           87.1          81.4
#
#       launch_angle  hit_location      bb_type  batter  pitcher
# 985             40             0     fly_ball  682985   623352
# 883             20             7   line_drive  668670   687911
# 125             40             9     fly_ball  514888   669373
# 445            -27             4  ground_ball  678009   664285
# 1045            30             7     fly_ball  514888   669373

# %%
# Save the filtered DataFrame to a CSV file
df_first_pitch.to_csv('first_pitch_swing_results.csv', index=False)

# %%
# Get unique pitch types in the 'pitch_type' column
df_first_pitch['pitch_type'].unique()
# Out:
# array(['SI', 'FF', 'CH', 'SL', 'CU', 'FC', 'ST', 'KC', 'FS', 'EP', 'FA',
#        'SV', 'KN', 'SC', 'CS', None, 'FO'], dtype=object)

# %%
# Replace None values in 'pitch_type' with 'Unknown'
df_first_pitch['pitch_type'] = df_first_pitch['pitch_type'].fillna('Unknown')

# Apply one-hot encoding to 'pitch_type'
df_pitch_encoded = pd.get_dummies(df_first_pitch['pitch_type'], prefix='pitch_type')

# Add the encoded columns back to the DataFrame
df_first_pitch = pd.concat([df_first_pitch, df_pitch_encoded], axis=1)

# Verify the changes
df_first_pitch.head()
# Out:
#          events    description pitch_type  release_speed  launch_speed  \
# 985      double  hit_into_play         SI           95.4          88.2
# 883      single  hit_into_play         FF           92.4          85.9
# 125   field_out  hit_into_play         CH           89.0          84.5
# 445   force_out  hit_into_play         SI           96.3          94.5
# 1045  field_out  hit_into_play         CH           87.1          81.4
#
#       launch_angle  hit_location      bb_type  batter  pitcher  ...  \
# 985             40             0     fly_ball  682985   623352  ...
# 883             20             7   line_drive  668670   687911  ...
# 125             40             9     fly_ball  514888   669373  ...
# 445            -27             4  ground_ball  678009   664285  ...
# 1045            30             7     fly_ball  514888   669373  ...
#
#       pitch_type_FO  pitch_type_FS  pitch_type_KC  pitch_type_KN  \
# 985           False          False          False          False
# 883           False          False          False          False
# 125           False          False          False          False
# 445           False          False          False          False
# 1045          False          False          False          False
#
#       pitch_type_SC  pitch_type_SI  pitch_type_SL  pitch_type_ST  \
# 985           False           True          False          False
# 883           False          False          False          False
# 125           False          False          False          False
# 445           False           True          False          False
# 1045          False          False          False          False
#
#       pitch_type_SV  pitch_type_Unknown
# 985           False               False
# 883           False               False
# 125           False               False
# 445           False               False
# 1045          False               False
#
# [5 rows x 27 columns]

# %%
# Select the numerical columns to scale
numerical_columns = ['release_speed', 'launch_speed', 'launch_angle']

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the numerical columns
df_first_pitch[numerical_columns] = scaler.fit_transform(df_first_pitch[numerical_columns])

# Verify the changes
df_first_pitch.head()
# Out:
#          events    description pitch_type  release_speed  launch_speed  \
# 985      double  hit_into_play         SI       0.933544     -0.026175
# 883      single  hit_into_play         FF       0.439291     -0.171918
# 125   field_out  hit_into_play         CH      -0.120862     -0.260631
# 445   force_out  hit_into_play         SI       1.081820      0.373034
# 1045  field_out  hit_into_play         CH      -0.433889     -0.457067
#
#       launch_angle  hit_location      bb_type  batter  pitcher  ...  \
# 985       0.882051             0     fly_ball  682985   623352  ...
# 883       0.193370             7   line_drive  668670   687911  ...
# 125       0.882051             9     fly_ball  514888   669373  ...
# 445      -1.425030             4  ground_ball  678009   664285  ...
# 1045      0.537710             7     fly_ball  514888   669373  ...
#
#       pitch_type_FO  pitch_type_FS  pitch_type_KC  pitch_type_KN  \
# 985           False          False          False          False
# 883           False          False          False          False
# 125           False          False          False          False
# 445           False          False          False          False
# 1045          False          False          False          False
#
#       pitch_type_SC  pitch_type_SI  pitch_type_SL  pitch_type_ST  \
# 985           False           True          False          False
# 883           False          False          False          False
# 125           False          False          False          False
# 445           False           True          False          False
# 1045          False          False          False          False
#
#       pitch_type_SV  pitch_type_Unknown
# 985           False               False
# 883           False               False
# 125           False               False
# 445           False               False
# 1045          False               False
#
# [5 rows x 27 columns]

# %%
# Define the successful outcomes, considering sac flies and sac bunts as hits
successful_outcomes = ['single', 'double', 'triple', 'home_run', 'sac_fly', 'sac_fly_double_play', 'sac_bunt']

# Create the target variable, treating sac flies and sac bunts as hits
df_first_pitch['target'] = df_first_pitch['events'].apply(lambda x: 1 if x in successful_outcomes else 0)

# Drop the 'events' column, as it's no longer needed
df_first_pitch = df_first_pitch.drop(columns=['events'])

# Verify the final dataset
df_first_pitch.head()
# Out:
#         description pitch_type  release_speed  launch_speed  launch_angle  \
# 985   hit_into_play         SI       0.933544     -0.026175      0.882051
# 883   hit_into_play         FF       0.439291     -0.171918      0.193370
# 125   hit_into_play         CH      -0.120862     -0.260631      0.882051
# 445   hit_into_play         SI       1.081820      0.373034     -1.425030
# 1045  hit_into_play         CH      -0.433889     -0.457067      0.537710
#
#       hit_location      bb_type  batter  pitcher  pitch_type_CH  ...  \
# 985              0     fly_ball  682985   623352          False  ...
# 883              7   line_drive  668670   687911          False  ...
# 125              9     fly_ball  514888   669373           True  ...
# 445              4  ground_ball  678009   664285          False  ...
# 1045             7     fly_ball  514888   669373           True  ...
#
#       pitch_type_FS  pitch_type_KC  pitch_type_KN  pitch_type_SC  \
# 985           False          False          False          False
# 883           False          False          False          False
# 125           False          False          False          False
# 445           False          False          False          False
# 1045          False          False          False          False
#
#       pitch_type_SI  pitch_type_SL  pitch_type_ST  pitch_type_SV  \
# 985            True          False          False          False
# 883           False          False          False          False
# 125           False          False          False          False
# 445            True          False          False          False
# 1045          False          False          False          False
#
#       pitch_type_Unknown  target
# 985                False       1
# 883                False       1
# 125                False       0
# 445                False       0
# 1045               False       0
#
# [5 rows x 27 columns]

# %%
# Save the final DataFrame to a CSV file
df_first_pitch.to_csv('first_pitch_swing_ml_ready.csv', index=False)

# %%
# One-hot encode the 'bb_type' column
df_bb_type_encoded = pd.get_dummies(df_first_pitch['bb_type'], prefix='bb_type')

# Add the encoded 'bb_type' columns back to the DataFrame
df_first_pitch = pd.concat([df_first_pitch, df_bb_type_encoded], axis=1)

# Verify the changes
df_first_pitch.head()
# Out:
#         description pitch_type  release_speed  launch_speed  launch_angle  \
# 985   hit_into_play         SI       0.933544     -0.026175      0.882051
# 883   hit_into_play         FF       0.439291     -0.171918      0.193370
# 125   hit_into_play         CH      -0.120862     -0.260631      0.882051
# 445   hit_into_play         SI       1.081820      0.373034     -1.425030
# 1045  hit_into_play         CH      -0.433889     -0.457067      0.537710
#
#       hit_location      bb_type  batter  pitcher  pitch_type_CH  ...  \
# 985              0     fly_ball  682985   623352          False  ...
# 883              7   line_drive  668670   687911          False  ...
# 125              9     fly_ball  514888   669373           True  ...
# 445              4  ground_ball  678009   664285          False  ...
# 1045             7     fly_ball  514888   669373           True  ...
#
#       pitch_type_SI  pitch_type_SL  pitch_type_ST  pitch_type_SV  \
# 985            True          False          False          False
# 883           False          False          False          False
# 125           False          False          False          False
# 445            True          False          False          False
# 1045          False          False          False          False
#
#       pitch_type_Unknown  target  bb_type_fly_ball  bb_type_ground_ball  \
# 985                False       1              True                False
# 883                False       1             False                False
# 125                False       0              True                False
# 445                False       0             False                 True
# 1045               False       0              True                False
#
#       bb_type_line_drive  bb_type_popup
# 985                False          False
# 883                 True          False
# 125                False          False
# 445                False          False
# 1045               False          False
#
# [5 rows x 31 columns]

# %%
# Drop the 'pitch_type', 'batter', 'pitcher', 'bb_type', and 'description' columns
df_first_pitch = df_first_pitch.drop(columns=['pitch_type', 'batter', 'pitcher', 'bb_type', 'description'])

# Verify the changes
df_first_pitch.head()
# Out:
#       release_speed  launch_speed  launch_angle  hit_location  pitch_type_CH  \
# 985        0.933544     -0.026175      0.882051             0          False
# 883        0.439291     -0.171918      0.193370             7          False
# 125       -0.120862     -0.260631      0.882051             9           True
# 445        1.081820      0.373034     -1.425030             4          False
# 1045      -0.433889     -0.457067      0.537710             7           True
#
#       pitch_type_CS  pitch_type_CU  pitch_type_EP  pitch_type_FA  \
# 985           False          False          False          False
# 883           False          False          False          False
# 125           False          False          False          False
# 445           False          False          False          False
# 1045          False          False          False          False
#
#       pitch_type_FC  ...  pitch_type_SI  pitch_type_SL  pitch_type_ST  \
# 985           False  ...           True          False          False
# 883           False  ...          False          False          False
# 125           False  ...          False          False          False
# 445           False  ...           True          False          False
# 1045          False  ...          False          False          False
#
#       pitch_type_SV  pitch_type_Unknown  target  bb_type_fly_ball  \
# 985           False               False       1              True
# 883           False               False       1             False
# 125           False               False       0              True
# 445           False               False       0             False
# 1045          False               False       0              True
#
#       bb_type_ground_ball  bb_type_line_drive  bb_type_popup
# 985                 False               False          False
# 883                 False                True          False
# 125                 False               False          False
# 445                  True               False          False
# 1045                False               False          False
#
# [5 rows x 26 columns]

# %%
# Save the cleaned DataFrame to a CSV file
df_first_pitch.to_csv('first_pitch_swing_ml_ready_cleaned.csv', index=False)
